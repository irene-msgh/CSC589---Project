# %% [markdown]
# # Exact multiple sequence alignment with bounding.

# %% [markdown]
# ![Description](Subject.png)

# %%
import numpy as np
from Bio.PDB import *
from Bio.Seq import Seq
import shutil
import warnings
import requests
import os
import pandas as pd
from Bio.PDB.PDBExceptions import PDBConstructionWarning
from Bio.PDB.DSSP import DSSP
from Bio import SeqIO
warnings.simplefilter('ignore', PDBConstructionWarning)

# %% [markdown]
# ### Similarity Matrix

# %%
def load_blosum(filename):
    """
    Load a substitution matrix (e.g. BLOSUM) from a file.

    Returns:
        dict: {(aa1, aa2): score}
    """
    matrix = {}

    with open(filename) as f:
        lines = f.readlines()

    # Ignore comments
    lines = [line.strip() for line in lines if line.strip() and not line.startswith("#")]

    # First non-comment line = column headers
    headers = lines[0].split()

    # Remaining lines = rows
    for line in lines[1:]:
        parts = line.split()
        row_aa = parts[0]
        scores = parts[1:]

        for col_aa, score in zip(headers, scores):
            matrix[(row_aa, col_aa)] = int(score)

    return matrix

blosum = load_blosum("BLOSUM62.txt")

# %% [markdown]
# ### Gap Parameters

# %%
gap = -4
gap_open = -11
gap_ext = -1

# %% [markdown]
# ### Needleman-Wunsh algorithm for any MSA of K input sequences
#
# Similarity column vs column

# %%
def score_column_vs_column(colA, colB, blosum, gap):
    total = 0
    count = 0

    for a in colA:
        for b in colB:
            # cas gap-gap
            if a == '-' and b == '-':
                continue

            # cas gap-aa
            if a == '-' or b == '-':
                total += gap
                count += 1
                continue

            # cas aa-aa
            if (a, b) in blosum:
                total += blosum[(a, b)]
            else:
                total += blosum[(b, a)]

            count += 1

    return total / count if count > 0 else 0.0

# %%
# Needleman-wunsh bloc-bloc affine

def needleman_wunsch_align_vs_align_affine(align1, align2, blosum, gap_open, gap_ext, gap_char="-"):
    n1, l1 = align1.shape
    n2, l2 = align2.shape
    NEG = -1e18

    # M: diag ; X: up (gap in align2) ; Y: left (gap in align1)
    matrix = np.full((l1+1, l2+1), NEG, dtype=float)
    X = np.full((l1+1, l2+1), NEG, dtype=float)
    Y = np.full((l1+1, l2+1), NEG, dtype=float)

    backtracking_matrix = np.full((l1+1, l2+1), -1, dtype=np.int8)  # prev state 0/1/2
    btX = np.full((l1+1, l2+1), -1, dtype=np.int8)
    btY = np.full((l1+1, l2+1), -1, dtype=np.int8)

    matrix[0,0] = 0.0
    backtracking_matrix[0,0] = 0
    # 1 = horiz ; 2 = vert ; 3 = diag

    # ---- CONSTRUCTION MATRICES ----
    # init first column (only X)
    for i in range(1, l1+1):
        if i == 1:
            X[i,0] = matrix[i-1,0] + gap_open + gap_ext
            btX[i,0] = 0
        else:
            X[i,0] = X[i-1,0] + gap_ext
            btX[i,0] = 1
            matrix[i,0] = NEG

    # init first row (only Y)
    for j in range(1, l2+1):
        if j == 1:
            Y[0,j] = matrix[0,j-1] + gap_open + gap_ext
            btY[0,j] = 0
        else:
            Y[0,j] = Y[0,j-1] + gap_ext
            btY[0,j] = 2
            matrix[0,j] = NEG


    for i in range(1,l1+1):
        for j in range(1,l2+1):                
            # X (up): either open from M or extend X
            open_x = matrix[i-1,j] + gap_open + gap_ext
            ext_x  = X[i-1,j] + gap_ext
            if open_x >= ext_x:
                X[i,j] = open_x
                btX[i,j] = 0
            else:
                X[i,j] = ext_x
                btX[i,j] = 1

            # Y (left): open from M or extend Y
            open_y = matrix[i,j-1] + gap_open + gap_ext
            ext_y  = Y[i,j-1] + gap_ext
            if open_y >= ext_y:
                Y[i,j] = open_y
                btY[i,j] = 0
            else:
                Y[i,j] = ext_y
                btY[i,j] = 2

            # M (diag): come from best previous state + column score
            s = score_column_vs_column(align1[:, i-1], align2[:, j-1], blosum, 0) #modifier score pour pas compter les gap 2 fois
            prev = [matrix[i-1,j-1], X[i-1,j-1], Y[i-1,j-1]]
            p = int(np.argmax(prev))
            matrix[i,j] = prev[p] + s
            backtracking_matrix[i,j] = p


    # choose best ending state
    i, j = l1, l2
    end = [matrix[i,j], X[i,j], Y[i,j]]
    state = int(np.argmax(end))
    score = end[state]

    # ---- BACKTRACKING ----
    cols1 = []
    cols2 = []

    i, j = l1, l2
    while i > 0 or j > 0:
        if state == 0:  # M: diag
            prev = backtracking_matrix[i,j]
            cols1.append(align1[:, i-1])
            cols2.append(align2[:, j-1])
            i -= 1; j -= 1
            state = int(prev)
        elif state == 1:  # X: up (gap in align2)
            prev = btX[i,j]
            cols1.append(align1[:, i-1])
            cols2.append(np.array([gap_char]*n2))
            i -= 1
            state = int(prev)
        else:  # Y: left (gap in align1)
            prev = btY[i,j]
            cols1.append(np.array([gap_char]*n1))
            cols2.append(align2[:, j-1])
            j -= 1
            state = int(prev)

    cols1.reverse()
    cols2.reverse()

    new1 = np.stack(cols1, axis=1)  # (n1, L)
    new2 = np.stack(cols2, axis=1)  # (n2, L)
    final_align = np.vstack([new1, new2])  # (n1+n2, L)     

    return new1, new2, matrix, score, final_align

# %%
#TEST ALIGN VS ALIGN AFFINE
print("========== TEST ALIGN VS ALIGN AFFINE ======")
align1 = np.array([
    list("CHAT"),
    list("C-AT")])

align2 = np.array([
    list("BAT"),
    list("CAT")])

new_align1, new_align2 , M, score, final_align = needleman_wunsch_align_vs_align_affine(align1, align2, blosum, gap_open, gap_ext, gap_char='-')

print("score:", score)
print(M)
print("new align:")
for row in final_align:
    print("".join(row))
# Out:
# ========== TEST ALIGN VS ALIGN AFFINE ======
# score: 0.0
# [[ 0.000e+00 -1.000e+18 -1.000e+18 -1.000e+18]
#  [-1.000e+18  3.000e+00 -1.200e+01 -1.400e+01]
#  [-1.000e+18 -1.275e+01  2.000e+00 -1.000e+01]
#  [-1.000e+18 -1.400e+01 -5.000e+00  2.000e+00]
#  [-1.000e+18 -1.500e+01 -1.000e+01  0.000e+00]]
# new align:
# CHAT
# C-AT
# B-AT
# C-AT

# %% [markdown]
# ### TO DO LIST
#
# - Carillo Lipman
#
# - Study and compare the performance of the algorithms. Estimate the performance of the non-bounded algorithm. Study the effect of different bounds.
#
# - How do exact alignments relate to heuristic alignments. Compare to available tools or your own implementation. Quantify and discuss differences.
#
# - Can you overcome any limitations of the bounding approach?
#
# - Trouver et fournir des exemples sur lesquels tester notre code

# %%
def column_score(column, blosum, gap):
	total = 0
	K = len(column)

	for k in range(K):
		for j in range(k+1, K):
			a = column[k]
			b = column[j]
			
			# cas gap-gap
			if a == '-' and b == '-':
				continue
			
			# cas gap-aa
			if a == '-' or b == '-':
				total += gap
				continue

			# cas aa-aa
			if (a, b) in blosum:
				total += blosum[(a, b)]
			else:
				total += blosum[(b, a)]

	return total

# %%
from itertools import product 

def K_maximum_similarity(sequences, blosum, gap):
	K = len(sequences)
	dimensions = np.array([len(seq) + 1 for seq in sequences])
	ranges = [range(d) for d in dimensions]
	S = np.zeros(dimensions, dtype=float)
	best_decisions = np.zeros(dimensions, dtype=int)  # to store the best state for backtracking
	
	# Initialization of S 
	
	S[tuple([0]*K)] = 0.0
	
	for idx in product(*ranges):
		# There are exactly 2^K - 1 possible previous states
		# We can represent each state as a K-bit binary number, where bit i is 1 if we take the character from sequence i, and 0 if we take a gap in sequence i.
		
		if idx == tuple([0]*K):
			continue
		max_score = -1e18
		best_state = None
		for state in range(1, 2**K):
			prev_idx = list(idx)
			score = 0.0
			valid = True
			column = []
			
			for i in range(K):
				if (state >> i) & 1: # we take a character from sequence i
					prev_idx[i] -= 1
					if prev_idx[i] < 0:
						valid = False
						break
					column.append(sequences[i][prev_idx[i]])  # gap column will be scored against this character
				else:  # it is a jump in sequence i
					column.append('-')
			
			if not valid:
				continue

			score = column_score(column, blosum, gap) + S[tuple(prev_idx)]

			if score > max_score:
				max_score = score
				best_state = state
		
		S[idx] = max_score
		best_decisions[idx] = best_state

	# Backtracking to reconstruct the alignment
	alignement = np.array([['']*(max(dimensions)-1+10) for i in range(K)], dtype=object)
	idx = tuple(dimensions - np.array([1]*K))  # start from the end
	idx_alignment = max(dimensions) - 2+10
	while idx != tuple([0]*K):
		state = best_decisions[idx]
		for i in range(K):
			if (state >> i) & 1:  # we took a character from sequence i
				alignement[i][idx_alignment] = sequences[i][idx[i]-1]
				idx = list(idx)
				idx[i] -= 1
				idx = tuple(idx)
			else:  # we took a gap in sequence i
				alignement[i][idx_alignment] = '-'
		idx_alignment -= 1


	return float(S[tuple(dimensions - np.array([1]*K))]), S, best_decisions, alignement

# %%
similarity, S_matrix, best_decisions, alignment = K_maximum_similarity(["ACCCGAG", "ACTACC", "TCCTACGG"], blosum, gap)
print("similarity:", similarity)
print("S matrix:")
print(S_matrix)
print("alignment:")
for row in alignment:
	print("".join(row))
# Out:
# similarity: 43.0
# S matrix:
# [[[  0.  -8. -16. -24. -32. -40. -48. -56. -64.]
#   [ -8.  -8. -16. -24. -32. -36. -44. -52. -60.]
#   [-16. -16.  -7. -15. -23. -31. -35. -43. -51.]
#   [-24. -19. -15. -16. -18. -26. -34. -42. -50.]
#   [-32. -27. -23. -23. -24. -22. -30. -38. -46.]
#   [-40. -35. -26. -22. -30. -30. -21. -29. -37.]
#   [-48. -43. -34. -25. -31. -38. -29. -32. -40.]]
#
#  [[ -8.  -8. -16. -24. -32. -36. -44. -52. -60.]
#   [ -4.   4.  -4. -12. -20. -20. -28. -36. -44.]
#   [-12.  -4.   5.  -3. -11. -19. -19. -27. -35.]
#   [-20. -11.  -3.  -4.  -6. -14. -22. -29. -37.]
#   [-28. -19. -11. -11. -12.  -6. -14. -22. -30.]
#   [-36. -27. -18. -10. -18. -14.  -5. -13. -21.]
#   [-44. -35. -26. -17. -19. -22. -13. -16. -24.]]
#
#  [[-16. -16.  -7. -15. -23. -31. -35. -43. -51.]
#   [-12.  -4.   5.  -3. -11. -19. -19. -27. -35.]
#   [ -3.   5.  31.  23.  15.   7.   7.  -1.  -9.]
#   [-11.  -3.  23.  22.  20.  12.   4.  -3. -11.]
#   [-19. -11.  15.  15.  14.  16.   8.   0.  -8.]
#   [-27. -18.   8.  16.   8.   8.  21.  13.   5.]
#   [-35. -26.   0.   9.   7.   0.  13.  10.   2.]]
#
#  [[-24. -24. -15.  -6. -14. -22. -30. -38. -46.]
#   [-20. -12.  -3.   6.  -2. -10. -18. -26. -34.]
#   [-11.  -3.  23.  32.  24.  16.   8.   0.  -8.]
#   [-12.   0.  22.  38.  30.  22.  14.   6.  -2.]
#   [-19.  -8.  15.  32.  30.  26.  21.  13.   5.]
#   [-18. -10.  16.  42.  34.  26.  43.  35.  27.]
#   [-26. -17.   9.  35.  33.  26.  35.  32.  24.]]
#
#  [[-32. -32. -23. -14. -15. -22. -21. -29. -37.]
#   [-28. -20. -11.  -2.  -3. -10.  -9. -17. -25.]
#   [-19. -11.  15.  24.  23.  16.  17.   9.   1.]
#   [-20.  -8.  14.  30.  35.  27.  23.  15.   7.]
#   [-20.  -8.  14.  31.  37.  34.  31.  23.  15.]
#   [-18.  -7.  19.  42.  39.  39.  53.  45.  37.]
#   [-17.  -9.  17.  43.  49.  43.  53.  46.  38.]]
#
#  [[-40. -40. -31. -22. -23. -23. -29. -23. -31.]
#   [-36. -28. -19. -10. -11. -11. -17. -11. -19.]
#   [-27. -19.   7.  16.  15.  15.   9.  15.   7.]
#   [-28. -16.   6.  22.  27.  27.  19.  21.  13.]
#   [-28. -16.   6.  23.  29.  39.  31.  29.  21.]
#   [-26. -15.  11.  34.  32.  34.  45.  51.  43.]
#   [-25. -17.   9.  35.  41.  41.  45.  53.  45.]]
#
#  [[-48. -48. -39. -30. -30. -27. -31. -31. -31.]
#   [-44. -36. -27. -18. -18. -11. -19. -19. -19.]
#   [-35. -27.  -1.   8.   8.  11.   7.   7.   7.]
#   [-35. -22.  -1.  14.  21.  23.  19.  13.  13.]
#   [-32. -20.   2.  18.  26.  39.  31.  23.  25.]
#   [-34. -23.   3.  26.  26.  33.  48.  43.  43.]
#   [-33. -23.   3.  27.  33.  37.  43.  45.  48.]]
#
#  [[-56. -56. -47. -38. -38. -35. -38. -33. -33.]
#   [-52. -44. -35. -26. -26. -19. -22. -21. -21.]
#   [-43. -35.  -9.   0.   0.   3.   0.   5.   5.]
#   [-43. -30.  -9.   6.  13.  15.  12.  17.  11.]
#   [-40. -28.  -6.  10.  18.  31.  28.  29.  21.]
#   [-42. -31.  -5.  18.  18.  28.  42.  46.  41.]
#   [-41. -31.  -5.  19.  25.  29.  37.  48.  43.]]]
# alignment:
# ACC--CGAG
# ACT-ACC--
# TCCTACG-G
